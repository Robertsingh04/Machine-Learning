# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.cluster import KMeans

# %%
Mall_df=pd.read_csv("C:/Users/PC/Documents/DATA/Mall_Customers.csv")   
Mall_df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
Mall_df["Gender"]=Mall_df["Gender"].replace({"Male":5,"Female":10})
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_24284\274497654.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Mall_df["Gender"]=Mall_df["Gender"].replace({"Male":5,"Female":10})

# %%
Mall_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       5   19                  15                      39
# 1             2       5   21                  15                      81
# 2             3      10   20                  16                       6
# 3             4      10   23                  16                      77
# 4             5      10   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196      10   35                 120                      79
# 196         197      10   45                 126                      28
# 197         198       5   32                 126                      74
# 198         199       5   32                 137                      18
# 199         200       5   30                 137                      83
#
# [200 rows x 5 columns]

# %%
sns.clustermap(Mall_df)
plt.savefig("tata.jpg")

# %%
Mall_wcss=[]
for i in range(1,200):
  model=KMeans(i)
  model.fit(Mall_df)
  Mall_wcss.append(model.inertia_)

# %%
Mall_wcss
# Out:
# [976694.7799999999,
#  388242.34983498347,
#  273303.7941989699,
#  196570.447740113,
#  176948.41996233523,
#  123805.1930054125,
#  104399.82004578432,
#  95484.20794513458,
#  78774.75968475969,
#  74780.84303343999,
#  66158.38713261377,
#  63611.67423317424,
#  58085.85210403632,
#  54030.693949617635,
#  53377.80981795982,
#  48061.10951940216,
#  44708.872355422354,
#  44281.23927594145,
#  42746.17936507936,
#  39810.88164335665,
#  37282.615728715726,
#  38047.823554223556,
#  35560.330158730154,
#  32958.31893939394,
#  31587.0672979798,
#  30550.954431679427,
#  31061.982520257516,
#  27946.072974101917,
#  27832.27193362193,
#  26071.772527472527,
#  24602.350854700853,
#  23967.190836940837,
#  23806.780952380952,
#  24296.199278499273,
#  21652.54227994228,
#  21177.17738095238,
#  19954.18373015873,
#  20301.813888888886,
#  19154.996608946607,
#  18260.523015873016,
#  18246.43928571428,
#  16933.91507936508,
#  17010.515476190478,
#  16373.942063492064,
# ...

# %%
sns.set()
plt.plot(range(1,200),Mall_wcss)
plt.show()

# %%
model=KMeans(10)
model.fit(Mall_df)
# Out:
# KMeans(n_clusters=10)

# %%
identify_cluster=model.fit_predict(Mall_df)
identify_cluster
# Out:
# array([1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4,
#        1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 3, 3,
#        1, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 7, 3, 8, 3, 8, 8, 7, 8, 8, 7,
#        7, 8, 8, 7, 8, 7, 7, 7, 8, 7, 8, 7, 7, 8, 8, 7, 8, 7, 8, 8, 8, 8,
#        8, 7, 7, 7, 7, 7, 8, 8, 8, 8, 7, 7, 7, 0, 5, 0, 5, 0, 5, 0, 5, 0,
#        5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 9, 0,
#        9, 0, 9, 0, 9, 0, 9, 0, 9, 0, 9, 6, 9, 6, 9, 6, 9, 6, 9, 6, 9, 6,
#        9, 6, 9, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6,
#        2, 6])

# %%
Mall_df["cluster"]=identify_cluster
Mall_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1       5   19                  15                      39
# 1             2       5   21                  15                      81
# 2             3      10   20                  16                       6
# 3             4      10   23                  16                      77
# 4             5      10   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196      10   35                 120                      79
# 196         197      10   45                 126                      28
# 197         198       5   32                 126                      74
# 198         199       5   32                 137                      18
# 199         200       5   30                 137                      83
#
#      cluster
# 0          1
# 1          4
# 2          1
# 3          4
# 4          1
# ...

# %%
Mall_df.cluster.value_counts()
# Out:
# cluster
# 3    36
# 1    22
# 4    22
# 8    22
# 7    21
# 0    21
# 6    18
# 5    14
# 9    14
# 2    10
# Name: count, dtype: int64

# %%
pd.set_option("display.max_rows",None)
Mall_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1       5   19                  15                      39
# 1             2       5   21                  15                      81
# 2             3      10   20                  16                       6
# 3             4      10   23                  16                      77
# 4             5      10   31                  17                      40
# 5             6      10   22                  17                      76
# 6             7      10   35                  18                       6
# 7             8      10   23                  18                      94
# 8             9       5   64                  19                       3
# 9            10      10   30                  19                      72
# 10           11       5   67                  19                      14
# 11           12      10   35                  19                      99
# ...
